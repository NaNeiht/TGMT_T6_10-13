# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/AnImg/messiwc.JPG'

# %%
#Doc anh
image = load_image(my_path)

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>

# %%
print(image.size)
# Out:
# (474, 474)

# %%
#Thay doi kich thuoc anh
new_size = (200,200)
new_img = image.resize(new_size)
display(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
new_mwc_path = "C:/Users/AnImg" + "/mwc.JPG"
image.save(new_mwc_path)
