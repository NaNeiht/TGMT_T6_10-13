# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/AnImg/messiwc.JPG'

# %%
#Doc anh
image = load_image(my_path)

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>

# %%
#Xoay anh
rotated_image = image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x474>

# %%
#Hoan doi vi tri anh
transposed_image = image.transpose(Image.Transpose.ROTATE_180)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x474>
