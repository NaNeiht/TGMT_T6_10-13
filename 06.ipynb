# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/AnImg/messiwc.JPG'

# %%
#Doc anh
image = load_image(my_path)

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>

# %%
gray_image = image.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=474x474>

# %%
#Phan RGB thanh 3 tang mau khac nhau
red_b, blue_b, green_b = image.split()
display(red_b)
display(blue_b)
display(green_b)
# Out:
# <PIL.Image.Image image mode=L size=474x474>
# <PIL.Image.Image image mode=L size=474x474>
# <PIL.Image.Image image mode=L size=474x474>

# %%
#Tron anh
merged_image = Image.merge("RGB", (red_b,blue_b,green_b))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x474>
