# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/AnImg/messiwc.JPG'

# %%
#Doc anh
image = load_image(my_path)

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>

# %%
#Dinh vi khu vuc cat
region = (250, 250, 350, 350)
cropped_img = image.crop(region)
display(cropped_img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
#Dan anh
paste_position = (75,275)
image.paste(cropped_img,paste_position)
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>
